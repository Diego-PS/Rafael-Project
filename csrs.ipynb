# %%
f = open('amcr/csrs_ppp/amcr0011_15.sum', 'r')
message = f.read()
print(message)
f.close()
# Out:
# HDR GRP CANADIAN GEODETIC SURVEY, SURVEYOR GENERAL BRANCH, NATURAL RESOURCES CANADA
# HDR ADR GOVERNMENT OF CANADA, 588 BOOTH STREET ROOM 334, OTTAWA ONTARIO K1A 0Y7
# HDR TEL 343-292-6617
# HDR EMA nrcan.geodeticinformation-informationgeodesique.rncan@canada.ca
# VER 3.50.2 (2021-12-08)
# NOW 2022-03-09 00:52:31.00
# RNX amcr0011_15.21o
# MKR AMCR
# MOD STATIC
# BEG 2021-01-01 12:00:00.00
# END 2021-01-01 12:15:00.00
# INT 30.00
# EPO 31 31 31
# EXE 0 sec
# OBS G C1C C2W L1W L2W
# OBS R C1P C2P L1P L2P
# PAR TYPE         SYS SIG SAT INIT      NOISE
# PAR POS_X                    1.000e+10 0.000e+00
# PAR POS_Y                    1.000e+10 0.000e+00
# PAR POS_Z                    1.000e+10 0.000e+00
# PAR TZD                      5.000e-02 5.000e-05
# PAR TZD_GRAD_N               3.000e-03 1.667e-06
# PAR TZD_GRAD_E               3.000e-03 1.667e-06
# PAR RX_CLK       G           1.000e+10 1.000e+10
# PAR RX_CLK       R           1.000e+10 1.000e+10
# ...
